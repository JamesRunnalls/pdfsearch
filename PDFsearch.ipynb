# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import numpy

# %%
# Search the text database
Search = 'gate valve'
dk = pd.read_csv('C:\\Users\\james.runnalls\\Documents\\Jupyter\\Output.csv', names=['FID', 'Text', 'Filename', 'Date Created'])
dk['Fuzz Score'] = dk.apply(lambda row: fuzz.WRatio(row['Text'],Search), axis=1)
dk = dk.sort_values(['Fuzz Score'], ascending=False)
#dk = dk.loc[dk['Fuzz Score'] > 60]
dk
# Out:
#       FID  \
# 7012  54
# 7019  61
# 632   33
# 5922  8
# 1078  12
# 7423  18
# 1087  21
# 7408  3
# 398   10
# 7594  17
# 5921  7
# 2170  15
# 2044  1
# 875   0
# 1101  35
# 5938  24
# 1076  10
# 4845  8
# 7577  0
# 4852  15
# 6995  37
# 4858  21
# 4970  22
# 7003  45
# 6670  43
# 2193  38
# 4952  4
# 4640  6
# 7442  17
# 6056  14
# ...   ..
# 3260  5
# 8451  23
# 3963  10
# 3877  34
# 6223  56
# 7989  10
# 7152  12
# 6840  16
# 1147  7
# 2990  19
# 310   47
# 4744  16
# 394   6
# 3827  20
# 3959  6
# 419   7
# 4832  12
# 420   8
# 3261  6
# 3263  8
# 8471  7
# 3264  9
# 3277  22
# 3461  69
# 4550  8
# 4823  3
# 3282  27
# 3283  28
# 5428  10
# 4552  10
#
# ...
